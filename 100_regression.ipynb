# %%
using Pkg

Pkg.add("DataFrames")
Pkg.add("GLM")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed Compat ────────────────────── v4.18.1
#    Installed PooledArrays ──────────────── v1.4.3
#    Installed SentinelArrays ────────────── v1.4.9
#    Installed TableTraits ───────────────── v1.0.1
#    Installed InvertedIndices ───────────── v1.3.1
#    Installed InlineStrings ─────────────── v1.4.5
#    Installed DataFrames ────────────────── v1.8.1
#    Installed DataValueInterfaces ───────── v1.0.0
#    Installed Crayons ───────────────────── v4.1.1
#    Installed Tables ────────────────────── v1.12.1
#    Installed PrettyTables ──────────────── v3.1.2
#    Installed IteratorInterfaceExtensions ─ v1.0.0
#    Installed StringManipulation ────────── v0.4.2
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [a93c6f00] + DataFrames v1.8.1
#     Updating `~/.julia/environments/v1.12/Manifest.toml`
#   [34da2185] + Compat v4.18.1
#   [a8cc5b0e] + Crayons v4.1.1
# ...

# %%
2*sqrt(2)
# Out:
# 2.8284271247461903

# %%
Pkg.add("StatsBase")
# Out:
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [2913bbd2] + StatsBase v0.34.10
#     Manifest No packages added to or removed from `~/.julia/environments/v1.12/Manifest.toml`

# %%
using DataFrames, GLM, StatsBase

# Create a sample DataFrame
data = DataFrame(X = [1, 2, 3, 4, 5], Y = [2, 4, 5, 4, 6])
# Out:
# 5×2 DataFrame
#  Row │ X      Y
#      │ Int64  Int64
# ─────┼──────────────
#    1 │     1      2
#    2 │     2      4
#    3 │     3      5
#    4 │     4      4
#    5 │     5      6

# %%
model = lm(@formula(Y ~ X), data)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# Y ~ 1 + X
#
# Coefficients:
# ────────────────────────────────────────────────────────────────────
#              Coef.  Std. Error     t  Pr(>|t|)  Lower 95%  Upper 95%
# ────────────────────────────────────────────────────────────────────
# (Intercept)    1.8    0.938083  1.92    0.1508  -1.1854      4.7854
# X              0.8    0.282843  2.83    0.0663  -0.100132    1.70013
# ────────────────────────────────────────────────────────────────────

# %%
println(summary(model))
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
